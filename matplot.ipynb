# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
data=np.arange(10)
plt.plot(data)

# %%
data_x = [2,4,6,8,10]
data_y = [0,4,7,8,10]

# %%
plt.plot(data_x,data_y)
plt.xlabel("weather")
plt.ylabel("temp")
plt.title("weather vs temp")
plt.show()
