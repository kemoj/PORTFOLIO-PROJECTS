# %%
import pandas as pd
import numpy as np

boston= pd.read_csv("C:/Users/HP/Desktop/Boston.csv")
print(boston)
# Out:
#      Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0             1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1             2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2             3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3             4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4             5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
# ..          ...      ...   ...    ...   ...    ...    ...   ...     ...  ...
# 501         502  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1
# 502         503  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1
# 503         504  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1
# 504         505  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1
# 505         506  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1
#
#      tax  ptratio   black  lstat  medv
# ...

# %%
boston.loc[boston["age"]>50,"tax"]
# Out:
# 0      296
# 1      242
# 2      242
# 4      222
# 5      222
#       ...
# 501    273
# 502    273
# 503    273
# 504    273
# 505    273
# Name: tax, Length: 359, dtype: int64

# %%
boston.iloc[0:5] #slicing rows
# Out:
#    Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0           1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1           2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2           3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3           4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4           5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
#
#    tax  ptratio   black  lstat  medv
# 0  296     15.3  396.90   4.98  24.0
# 1  242     17.8  396.90   9.14  21.6
# 2  242     17.8  392.83   4.03  34.7
# 3  222     18.7  394.63   2.94  33.4
# 4  222     18.7  396.90   5.33  36.2

# %%
boston.iloc[0:5,10:20]  #slicing rows and column
# Out:
#    tax  ptratio   black  lstat  medv
# 0  296     15.3  396.90   4.98  24.0
# 1  242     17.8  396.90   9.14  21.6
# 2  242     17.8  392.83   4.03  34.7
# 3  222     18.7  394.63   2.94  33.4
# 4  222     18.7  396.90   5.33  36.2

# %%
boston.iloc[1:3, ]
# Out:
#    Unnamed: 0     crim   zn  indus  chas    nox     rm   age     dis  rad  \
# 1           2  0.02731  0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2           3  0.02729  0.0   7.07     0  0.469  7.185  61.1  4.9671    2
#
#    tax  ptratio   black  lstat  medv
# 1  242     17.8  396.90   9.14  21.6
# 2  242     17.8  392.83   4.03  34.7

# %%
boston.iloc[ : ,0:5]
# Out:
#      Unnamed: 0     crim    zn  indus  chas
# 0             1  0.00632  18.0   2.31     0
# 1             2  0.02731   0.0   7.07     0
# 2             3  0.02729   0.0   7.07     0
# 3             4  0.03237   0.0   2.18     0
# 4             5  0.06905   0.0   2.18     0
# ..          ...      ...   ...    ...   ...
# 501         502  0.06263   0.0  11.93     0
# 502         503  0.04527   0.0  11.93     0
# 503         504  0.06076   0.0  11.93     0
# 504         505  0.10959   0.0  11.93     0
# 505         506  0.04741   0.0  11.93     0
#
# [506 rows x 5 columns]

# %%
boston.iloc[5,5] #for missing value #data cleaning
# Out:
# 0.458

# %%
boston["tax"].sum()
# Out:
# 206568

# %%
boston.sum()
# Out:
# Unnamed: 0    128271.00000
# crim            1828.44292
# zn              5750.00000
# indus           5635.21000
# chas              35.00000
# nox              280.67570
# rm              3180.02500
# age            34698.90000
# dis             1920.29160
# rad             4832.00000
# tax           206568.00000
# ptratio         9338.50000
# black         180477.06000
# lstat           6402.45000
# medv           11401.60000
# dtype: float64

# %%
boston.mean(axis=1)
# Out:
# 0      55.726621
# 1      52.619627
# 2      51.811893
# 3      49.346705
# 4      50.483083
#          ...
# 501    87.453149
# 502    88.149051
# 503    89.209817
# 504    88.868366
# 505    87.971027
# Length: 506, dtype: float64

# %%
boston.mean
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of      Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0             1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1             2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2             3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3             4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4             5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
# ..          ...      ...   ...    ...   ...    ...    ...   ...     ...  ...
# 501         502  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1
# 502         503  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1
# 503         504  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1
# 504         505  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1
# ...

# %%
boston.mean(axis=1,skipna=False)
# Out:
# 0      55.726621
# 1      52.619627
# 2      51.811893
# 3      49.346705
# 4      50.483083
#          ...
# 501    87.453149
# 502    88.149051
# 503    89.209817
# 504    88.868366
# 505    87.971027
# Length: 506, dtype: float64

# %%
boston.idxmax()
# Out:
# Unnamed: 0    505
# crim          380
# zn             57
# indus         488
# chas          142
# nox           142
# rm            364
# age             8
# dis           353
# rad           356
# tax           488
# ptratio       354
# black           0
# lstat         374
# medv          161
# dtype: int64

# %%
boston["tax"].mean()
# Out:
# 408.2371541501976

# %%
boston.idxmin()
# Out:
# Unnamed: 0      0
# crim            0
# zn              1
# indus         195
# chas            0
# nox           286
# rm            365
# age            41
# dis           372
# rad             0
# tax           353
# ptratio       196
# black         450
# lstat         161
# medv          398
# dtype: int64

# %%
boston.cumsum()
# Out:
#      Unnamed: 0        crim      zn    indus  chas       nox        rm  \
# 0             1     0.00632    18.0     2.31     0    0.5380     6.575
# 1             3     0.03363    18.0     9.38     0    1.0070    12.996
# 2             6     0.06092    18.0    16.45     0    1.4760    20.181
# 3            10     0.09329    18.0    18.63     0    1.9340    27.179
# 4            15     0.16234    18.0    20.81     0    2.3920    34.326
# ..          ...         ...     ...      ...   ...       ...       ...
# 501      126253  1828.17989  5750.0  5587.49    35  278.3837  3154.105
# 502      126756  1828.22516  5750.0  5599.42    35  278.9567  3160.225
# 503      127260  1828.28592  5750.0  5611.35    35  279.5297  3167.201
# 504      127765  1828.39551  5750.0  5623.28    35  280.1027  3173.995
# 505      128271  1828.44292  5750.0  5635.21    35  280.6757  3180.025
#
#          age        dis   rad     tax  ptratio      black    lstat     medv
# ...

# %%
boston.describe()
# Out:
#        Unnamed: 0        crim          zn       indus        chas         nox  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean   253.500000    3.613524   11.363636   11.136779    0.069170    0.554695
# std    146.213884    8.601545   23.322453    6.860353    0.253994    0.115878
# min      1.000000    0.006320    0.000000    0.460000    0.000000    0.385000
# 25%    127.250000    0.082045    0.000000    5.190000    0.000000    0.449000
# 50%    253.500000    0.256510    0.000000    9.690000    0.000000    0.538000
# 75%    379.750000    3.677083   12.500000   18.100000    0.000000    0.624000
# max    506.000000   88.976200  100.000000   27.740000    1.000000    0.871000
#
#                rm         age         dis         rad         tax     ptratio  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     6.284634   68.574901    3.795043    9.549407  408.237154   18.455534
# ...

# %%
boston.reindex(index=[0,2,4,5],columns=["chas","age","dis","rad"])
# Out:
#    chas   age     dis  rad
# 0     0  65.2  4.0900    1
# 2     0  61.1  4.9671    2
# 4     0  54.2  6.0622    3
# 5     0  58.7  6.0622    3

# %%
boston.iloc[:3,0]
# Out:
# 0    1
# 1    2
# 2    3
# Name: Unnamed: 0, dtype: int64

# %%
#conditional selection
boston.age==50
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 501    False
# 502    False
# 503    False
# 504    False
# 505    False
# Name: age, Length: 506, dtype: bool

# %%
boston.age>50
# Out:
# 0       True
# 1       True
# 2       True
# 3      False
# 4       True
#        ...
# 501     True
# 502     True
# 503     True
# 504     True
# 505     True
# Name: age, Length: 506, dtype: bool

# %%
boston.age<50
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 501    False
# 502    False
# 503    False
# 504    False
# 505    False
# Name: age, Length: 506, dtype: bool

# %%
#sorting data #sort by label or actualvalue#
boston.sort_index()
# Out:
#      Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0             1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1             2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2             3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3             4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4             5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
# ..          ...      ...   ...    ...   ...    ...    ...   ...     ...  ...
# 501         502  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1
# 502         503  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1
# 503         504  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1
# 504         505  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1
# 505         506  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1
#
#      tax  ptratio   black  lstat  medv
# ...

# %%
boston.sort_index(ascending = False)
# Out:
#      Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 505         506  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1
# 504         505  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1
# 503         504  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1
# 502         503  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1
# 501         502  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1
# ..          ...      ...   ...    ...   ...    ...    ...   ...     ...  ...
# 4             5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
# 3             4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 2             3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 1             2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 0             1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
#
#      tax  ptratio   black  lstat  medv
# ...

# %%
boston.sort_index(axis = 1)
# Out:
#      Unnamed: 0   age   black  chas     crim     dis  indus  lstat  medv  \
# 0             1  65.2  396.90     0  0.00632  4.0900   2.31   4.98  24.0
# 1             2  78.9  396.90     0  0.02731  4.9671   7.07   9.14  21.6
# 2             3  61.1  392.83     0  0.02729  4.9671   7.07   4.03  34.7
# 3             4  45.8  394.63     0  0.03237  6.0622   2.18   2.94  33.4
# 4             5  54.2  396.90     0  0.06905  6.0622   2.18   5.33  36.2
# ..          ...   ...     ...   ...      ...     ...    ...    ...   ...
# 501         502  69.1  391.99     0  0.06263  2.4786  11.93   9.67  22.4
# 502         503  76.7  396.90     0  0.04527  2.2875  11.93   9.08  20.6
# 503         504  91.0  396.90     0  0.06076  2.1675  11.93   5.64  23.9
# 504         505  89.3  393.45     0  0.10959  2.3889  11.93   6.48  22.0
# 505         506  80.8  396.90     0  0.04741  2.5050  11.93   7.88  11.9
#
#        nox  ptratio  rad     rm  tax    zn
# 0    0.538     15.3    1  6.575  296  18.0
# ...

# %%
boston.sort_values(by=["age"])
# Out:
#      Unnamed: 0      crim   zn  indus  chas    nox     rm    age     dis  rad  \
# 41           42   0.12744  0.0   6.91     0  0.448  6.770    2.9  5.7209    3
# 74           75   0.07896  0.0  12.83     0  0.437  6.273    6.0  4.2515    5
# 73           74   0.19539  0.0  10.81     0  0.413  6.245    6.2  5.2873    4
# 43           44   0.15936  0.0   6.91     0  0.448  6.211    6.5  5.7209    3
# 70           71   0.08826  0.0  10.81     0  0.413  6.417    6.6  5.2873    4
# ..          ...       ...  ...    ...   ...    ...    ...    ...     ...  ...
# 386         387  24.39380  0.0  18.10     0  0.700  4.652  100.0  1.4672   24
# 158         159   1.34284  0.0  19.58     0  0.605  6.066  100.0  1.7573    5
# 383         384   7.99248  0.0  18.10     0  0.700  5.520  100.0  1.5331   24
# 406         407  20.71620  0.0  18.10     0  0.659  4.138  100.0  1.1781   24
# 420         421  11.08740  0.0  18.10     0  0.718  6.411  100.0  1.8589   24
#
# ...

# %%
boston.sort_values(by=["age","tax"])
# Out:
#      Unnamed: 0      crim   zn  indus  chas    nox     rm    age     dis  rad  \
# 41           42   0.12744  0.0   6.91     0  0.448  6.770    2.9  5.7209    3
# 74           75   0.07896  0.0  12.83     0  0.437  6.273    6.0  4.2515    5
# 73           74   0.19539  0.0  10.81     0  0.413  6.245    6.2  5.2873    4
# 43           44   0.15936  0.0   6.91     0  0.448  6.211    6.5  5.7209    3
# 42           43   0.14150  0.0   6.91     0  0.448  6.169    6.6  5.7209    3
# ..          ...       ...  ...    ...   ...    ...    ...    ...     ...  ...
# 418         419  73.53410  0.0  18.10     0  0.679  5.957  100.0  1.8026   24
# 420         421  11.08740  0.0  18.10     0  0.718  6.411  100.0  1.8589   24
# 437         438  15.17720  0.0  18.10     0  0.740  6.152  100.0  1.9142   24
# 442         443   5.66637  0.0  18.10     0  0.740  6.219  100.0  2.0048   24
# 443         444   9.96654  0.0  18.10     0  0.740  6.485  100.0  1.9784   24
#
# ...

# %%
boston.product()
# Out:
# Unnamed: 0     0.000000e+00
# crim          3.138946e-172
# zn             0.000000e+00
# indus                   inf
# chas           0.000000e+00
# nox           8.810725e-135
# rm                      inf
# age                     inf
# dis           1.184930e+261
# rad            0.000000e+00
# tax            0.000000e+00
# ptratio                 inf
# black                   inf
# lstat                   inf
# medv                    inf
# dtype: float64

# %%
boston.cumprod()
# Out:
#      Unnamed: 0           crim    zn       indus  chas            nox  \
# 0             1   6.320000e-03  18.0    2.310000     0   5.380000e-01
# 1             2   1.725992e-04   0.0   16.331700     0   2.523220e-01
# 2             6   4.710232e-06   0.0  115.465119     0   1.183390e-01
# 3            24   1.524702e-07   0.0  251.713959     0   5.419927e-02
# 4           120   1.052807e-08   0.0  548.736432     0   2.482327e-02
# ..          ...            ...   ...         ...   ...            ...
# 501           0  2.196417e-167   0.0         inf     0  8.173220e-134
# 502           0  9.943179e-169   0.0         inf     0  4.683255e-134
# 503           0  6.041476e-170   0.0         inf     0  2.683505e-134
# 504           0  6.620853e-171   0.0         inf     0  1.537648e-134
# 505           0  3.138946e-172   0.0         inf     0  8.810725e-135
#
#                rm           age            dis  rad           tax  \
# ...

# %%
Ds= boston.age
print(Ds)
# Out:
# 0      65.2
# 1      78.9
# 2      61.1
# 3      45.8
# 4      54.2
#        ...
# 501    69.1
# 502    76.7
# 503    91.0
# 504    89.3
# 505    80.8
# Name: age, Length: 506, dtype: float64

# %%
np.ceil(Ds)
# Out:
# 0      66.0
# 1      79.0
# 2      62.0
# 3      46.0
# 4      55.0
#        ...
# 501    70.0
# 502    77.0
# 503    91.0
# 504    90.0
# 505    81.0
# Name: age, Length: 506, dtype: float64

# %%
np.floor(Ds)
# Out:
# 0      65.0
# 1      78.0
# 2      61.0
# 3      45.0
# 4      54.0
#        ...
# 501    69.0
# 502    76.0
# 503    91.0
# 504    89.0
# 505    80.0
# Name: age, Length: 506, dtype: float64

# %%
np.sort(Ds)
# Out:
# array([  2.9,   6. ,   6.2,   6.5,   6.6,   6.6,   6.8,   7.8,   7.8,
#          8.4,   8.9,   9.8,   9.9,  10. ,  13. ,  13.9,  14.7,  15.3,
#         15.7,  15.8,  16.3,  17. ,  17.2,  17.5,  17.5,  17.7,  17.8,
#         18.4,  18.4,  18.5,  18.5,  18.8,  19.1,  19.5,  20.1,  20.8,
#         21.1,  21.4,  21.4,  21.4,  21.5,  21.8,  21.9,  21.9,  22.3,
#         22.9,  23.3,  23.4,  24.8,  25.8,  26.3,  27.6,  27.7,  27.7,
#         27.9,  28.1,  28.4,  28.8,  28.9,  28.9,  29.1,  29.2,  29.3,
#         29.7,  30.2,  30.8,  31.1,  31.1,  31.3,  31.5,  31.9,  31.9,
#         32. ,  32. ,  32.1,  32.2,  32.2,  32.2,  32.3,  32.9,  33. ,
#         33.1,  33.2,  33.3,  33.5,  33.8,  34.1,  34.2,  34.5,  34.5,
#         34.9,  35.7,  35.9,  36.1,  36.6,  36.6,  36.6,  36.8,  36.9,
#         37.2,  37.3,  37.8,  38.1,  38.3,  38.4,  38.5,  38.9,  39. ,
#         40. ,  40.1,  40.3,  40.4,  40.5,  41.1,  41.1,  41.5,  41.9,
# ...

# %%
Ds.mean()
# Out:
# 68.57490118577078

# %%
np.mean(Ds)
# Out:
# 68.57490118577078

# %%
Ds.median()
# Out:
# 77.5

# %%
Ds.mode()
# Out:
# 0    100.0
# dtype: float64

# %%
Ds.describe()
# Out:
# count    506.000000
# mean      68.574901
# std       28.148861
# min        2.900000
# 25%       45.025000
# 50%       77.500000
# 75%       94.075000
# max      100.000000
# Name: age, dtype: float64
