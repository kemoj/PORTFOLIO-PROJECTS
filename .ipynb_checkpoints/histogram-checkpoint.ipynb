# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
scores=(30,10,33,24,2,14,67,80,52,77,45,21,66,43,10,8,55,32,11,92)
print(scores)
bins=[0,25,50,75,100]
plt.figure()
plt.hist(scores,bins)
plt.title("student scores")
plt.x_label("mark")
plt.y_label("no of stdents")
# Out:
# (30, 10, 33, 24, 2, 14, 67, 80, 52, 77, 45, 21, 66, 43, 10, 8, 55, 32, 11, 92)

# %%
# Out:
#        Country Name  Country ISO3   Year  Indicator Name  Indicator Code  \
# 0             False         False  False           False           False
# 1             False         False  False           False           False
# 2             False         False  False           False           False
# 3             False         False  False           False           False
# 4             False         False  False           False           False
# ...             ...           ...    ...             ...             ...
# 72146         False         False  False           False           False
# 72147         False         False  False           False           False
# 72148         False         False  False           False           False
# 72149         False         False  False           False           False
# 72150         False         False  False           False           False
#
#        Value
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# ...

# %%
ind.dropna()
# Out:
#         Country Name   Country ISO3        Year  \
# 0      #country+name  #country+code  #date+year
# 1            Nigeria            NGA        2007
# 2            Nigeria            NGA        2006
# 3            Nigeria            NGA        2005
# 4            Nigeria            NGA        2004
# ...              ...            ...         ...
# 72146        Nigeria            NGA        1981
# 72147        Nigeria            NGA        1980
# 72148        Nigeria            NGA        1979
# 72149        Nigeria            NGA        1978
# 72150        Nigeria            NGA        1977
#
#                                           Indicator Name     Indicator Code  \
# 0                                        #indicator+name    #indicator+code
# 1                       Agricultural machinery, tractors     AG.AGR.TRAC.NO
# 2                       Agricultural machinery, tractors     AG.AGR.TRAC.NO
# 3                       Agricultural machinery, tractors     AG.AGR.TRAC.NO
# ...
