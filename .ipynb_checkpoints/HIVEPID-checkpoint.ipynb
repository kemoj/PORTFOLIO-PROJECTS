# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
hiv= pd.read_excel("HIV_Epidemiology_Children_Adolescents_2021.xlsx", "Data")
hiv
# Out:
#        Key HIV epidemiology indicators for children and adolescents aged 0-19, 2000-2020  \
# 0                                                    ISO3
# 1                                                03M49WLD
# 2                                                03M49WLD
# 3                                                03M49WLD
# 4                                                03M49WLD
# ...                                                   ...
# 173249                                          regionWCA
# 173250                                          regionWCA
# 173251                                          regionWCA
# 173252                                          regionWCA
# 173253                                          regionWCA
#
#        Unnamed: 1               Unnamed: 2     Unnamed: 3  \
# 0            Type           Country/Region  UNICEF Region
# 1          Region                   Global            NaN
# 2          Region                   Global            NaN
# ...

# %%
Hiv=hiv.rename(columns=hiv.iloc[0]).loc[1:]
Hiv.head(10)
# Out:
#         ISO3    Type Country/Region UNICEF Region  \
# 1   03M49WLD  Region         Global           NaN
# 2   03M49WLD  Region         Global           NaN
# 3   03M49WLD  Region         Global           NaN
# 4   03M49WLD  Region         Global           NaN
# 5   03M49WLD  Region         Global           NaN
# 6   03M49WLD  Region         Global           NaN
# 7   03M49WLD  Region         Global           NaN
# 8   03M49WLD  Region         Global           NaN
# 9   03M49WLD  Region         Global           NaN
# 10  03M49WLD  Region         Global           NaN
#
#                                             Indicator            Data source  \
# 1   Estimated incidence rate (new HIV infection pe...  UNAIDS 2021 estimates
# 2   Estimated incidence rate (new HIV infection pe...  UNAIDS 2021 estimates
# 3   Estimated incidence rate (new HIV infection pe...  UNAIDS 2021 estimates
# 4   Estimated incidence rate (new HIV infection pe...  UNAIDS 2021 estimates
# ...

# %%
Hiv['Indicator'].unique()
# Out:
# array(['Estimated incidence rate (new HIV infection per 1,000 uninfected population)',
#        'Estimated mother-to-child transmission rate (%)',
#        'Estimated number of annual AIDS-related deaths',
#        'Estimated number of annual new HIV infections',
#        'Estimated number of people living with HIV',
#        'Estimated rate of annual AIDS-related deaths (per 100,000 population)'],
#       dtype=object)

# %%
indicator1=Hiv[Hiv["Indicator"]=='Estimated incidence rate (new HIV infection per 1,000 uninfected population)']
indicator1
# Out:
#              ISO3    Type           Country/Region UNICEF Region  \
# 1        03M49WLD  Region                   Global           NaN
# 2        03M49WLD  Region                   Global           NaN
# 3        03M49WLD  Region                   Global           NaN
# 4        03M49WLD  Region                   Global           NaN
# 5        03M49WLD  Region                   Global           NaN
# ...           ...     ...                      ...           ...
# 171716  regionWCA  Region  West and Central Africa           NaN
# 171717  regionWCA  Region  West and Central Africa           NaN
# 171718  regionWCA  Region  West and Central Africa           NaN
# 171719  regionWCA  Region  West and Central Africa           NaN
# 171720  regionWCA  Region  West and Central Africa           NaN
#
#                                                 Indicator  \
# 1       Estimated incidence rate (new HIV infection pe...
# 2       Estimated incidence rate (new HIV infection pe...
# ...

# %%
indicator1.to_csv("indicator1.csv",index=None)

# %%
Ind1=indicator1[(indicator1["Country/Region"]== "Global") & (indicator1["Sex"]=="Both") & (indicator1["Age"]=="Age 0-14")]
Ind1
# Out:
#          ISO3    Type Country/Region UNICEF Region  \
# 1    03M49WLD  Region         Global           NaN
# 7    03M49WLD  Region         Global           NaN
# 13   03M49WLD  Region         Global           NaN
# 19   03M49WLD  Region         Global           NaN
# 25   03M49WLD  Region         Global           NaN
# 31   03M49WLD  Region         Global           NaN
# 37   03M49WLD  Region         Global           NaN
# 43   03M49WLD  Region         Global           NaN
# 49   03M49WLD  Region         Global           NaN
# 55   03M49WLD  Region         Global           NaN
# 61   03M49WLD  Region         Global           NaN
# 67   03M49WLD  Region         Global           NaN
# 73   03M49WLD  Region         Global           NaN
# 79   03M49WLD  Region         Global           NaN
# 85   03M49WLD  Region         Global           NaN
# 91   03M49WLD  Region         Global           NaN
# 97   03M49WLD  Region         Global           NaN
# ...

# %%
x= Ind1["Year"]
y=Ind1["Value"]
plt.figure(figsize =(10,6))
plt.plot(x,y)
plt.xlabel("Year")
plt.ylabel("Value")
plt.title('The Graph of Hiv in Children and adolescence Age 0-14 in both Sex Across Year 2000 - 2020')
plt.show()

# %%
x= Ind1["Year"]
y=Ind1["Value"]
plt.figure(figsize =(10,6))
plt.plot(x,y)
plt.xlabel("Year")
plt.ylabel("Value")
plt.title('The Graph of Hiv in Children and adolescence Age 0-14 in both Sex Across Year 2000 - 2020')
plt.gca().invert_yaxis()

# %%
Ind2=indicator1[(indicator1["Country/Region"]== "West and Central Africa") & (indicator1["Sex"]=="Both") & (indicator1["Age"]=="Age 0-14")]
Ind2
# Out:
#              ISO3    Type           Country/Region UNICEF Region  \
# 171595  regionWCA  Region  West and Central Africa           NaN
# 171601  regionWCA  Region  West and Central Africa           NaN
# 171607  regionWCA  Region  West and Central Africa           NaN
# 171613  regionWCA  Region  West and Central Africa           NaN
# 171619  regionWCA  Region  West and Central Africa           NaN
# 171625  regionWCA  Region  West and Central Africa           NaN
# 171631  regionWCA  Region  West and Central Africa           NaN
# 171637  regionWCA  Region  West and Central Africa           NaN
# 171643  regionWCA  Region  West and Central Africa           NaN
# 171649  regionWCA  Region  West and Central Africa           NaN
# 171655  regionWCA  Region  West and Central Africa           NaN
# 171661  regionWCA  Region  West and Central Africa           NaN
# 171667  regionWCA  Region  West and Central Africa           NaN
# ...

# %%
x= Ind2["Year"]
y=Ind2["Value"]
plt.figure(figsize =(10,6))
plt.scatter(x,y)
plt.xlabel("Year")
plt.ylabel("Value")
plt.title('The Graph of Hiv in Children and adolescence Age 0-14 in both Sex Across Year 2000 - 2020')
plt.gca().invert_yaxis()

# %%
Ind3=indicator1[(indicator1["Country/Region"]== "Nigeria") & (indicator1["Sex"]=="Both") & (indicator1["Age"]=="Age 0-14")]
Ind3
# Out:
#        ISO3     Type Country/Region            UNICEF Region  \
# 102748  NGA  Country        Nigeria  West and Central Africa
# 102754  NGA  Country        Nigeria  West and Central Africa
# 102760  NGA  Country        Nigeria  West and Central Africa
# 102766  NGA  Country        Nigeria  West and Central Africa
# 102772  NGA  Country        Nigeria  West and Central Africa
# 102778  NGA  Country        Nigeria  West and Central Africa
# 102784  NGA  Country        Nigeria  West and Central Africa
# 102790  NGA  Country        Nigeria  West and Central Africa
# 102796  NGA  Country        Nigeria  West and Central Africa
# 102802  NGA  Country        Nigeria  West and Central Africa
# 102808  NGA  Country        Nigeria  West and Central Africa
# 102814  NGA  Country        Nigeria  West and Central Africa
# 102820  NGA  Country        Nigeria  West and Central Africa
# 102826  NGA  Country        Nigeria  West and Central Africa
# ...

# %%
x= Ind3["Year"]
y=Ind3["Value"]
plt.figure(figsize =(10,6))
plt.scatter(x,y)
plt.xlabel("Year")
plt.ylabel("Value")
plt.title('The Graph of Hiv in Children and adolescence Age 0-14 in both Sex Across Year 2000 - 2020')
plt.gca().invert_yaxis()

# %%
Indicator2= Hiv[Hiv["Indicator"]=='Estimated mother-to-child transmission rate (%)']
Indicator2
# Out:
#              ISO3    Type           Country/Region UNICEF Region  \
# 127      03M49WLD  Region                   Global           NaN
# 128      03M49WLD  Region                   Global           NaN
# 129      03M49WLD  Region                   Global           NaN
# 130      03M49WLD  Region                   Global           NaN
# 131      03M49WLD  Region                   Global           NaN
# ...           ...     ...                      ...           ...
# 171737  regionWCA  Region  West and Central Africa           NaN
# 171738  regionWCA  Region  West and Central Africa           NaN
# 171739  regionWCA  Region  West and Central Africa           NaN
# 171740  regionWCA  Region  West and Central Africa           NaN
# 171741  regionWCA  Region  West and Central Africa           NaN
#
#                                               Indicator  \
# 127     Estimated mother-to-child transmission rate (%)
# 128     Estimated mother-to-child transmission rate (%)
# ...

# %%
Indicator3= Hiv[Hiv["Indicator"]=='Estimated number of annual AIDS-related deaths']
Indicator3
# Out:
#              ISO3    Type           Country/Region UNICEF Region  \
# 148      03M49WLD  Region                   Global           NaN
# 149      03M49WLD  Region                   Global           NaN
# 150      03M49WLD  Region                   Global           NaN
# 151      03M49WLD  Region                   Global           NaN
# 152      03M49WLD  Region                   Global           NaN
# ...           ...     ...                      ...           ...
# 172241  regionWCA  Region  West and Central Africa           NaN
# 172242  regionWCA  Region  West and Central Africa           NaN
# 172243  regionWCA  Region  West and Central Africa           NaN
# 172244  regionWCA  Region  West and Central Africa           NaN
# 172245  regionWCA  Region  West and Central Africa           NaN
#
#                                              Indicator            Data source  \
# 148     Estimated number of annual AIDS-related deaths  UNAIDS 2021 estimates
# ...

# %%
Indicator4= Hiv[Hiv["Indicator"]== 'Estimated number of annual new HIV infections']
Indicator4
# Out:
#              ISO3    Type           Country/Region UNICEF Region  \
# 652      03M49WLD  Region                   Global           NaN
# 653      03M49WLD  Region                   Global           NaN
# 654      03M49WLD  Region                   Global           NaN
# 655      03M49WLD  Region                   Global           NaN
# 656      03M49WLD  Region                   Global           NaN
# ...           ...     ...                      ...           ...
# 172619  regionWCA  Region  West and Central Africa           NaN
# 172620  regionWCA  Region  West and Central Africa           NaN
# 172621  regionWCA  Region  West and Central Africa           NaN
# 172622  regionWCA  Region  West and Central Africa           NaN
# 172623  regionWCA  Region  West and Central Africa           NaN
#
#                                             Indicator            Data source  \
# 652     Estimated number of annual new HIV infections  UNAIDS 2021 estimates
# ...

# %%
Indicator5= Hiv[Hiv["Indicator"]=='Estimated number of people living with HIV']
Indicator5
# Out:
#              ISO3    Type           Country/Region UNICEF Region  \
# 1030     03M49WLD  Region                   Global           NaN
# 1031     03M49WLD  Region                   Global           NaN
# 1032     03M49WLD  Region                   Global           NaN
# 1033     03M49WLD  Region                   Global           NaN
# 1034     03M49WLD  Region                   Global           NaN
# ...           ...     ...                      ...           ...
# 173123  regionWCA  Region  West and Central Africa           NaN
# 173124  regionWCA  Region  West and Central Africa           NaN
# 173125  regionWCA  Region  West and Central Africa           NaN
# 173126  regionWCA  Region  West and Central Africa           NaN
# 173127  regionWCA  Region  West and Central Africa           NaN
#
#                                          Indicator            Data source  \
# 1030    Estimated number of people living with HIV  UNAIDS 2021 estimates
# ...

# %%
Indicator6= Hiv[Hiv["Indicator"]=='Estimated rate of annual AIDS-related deaths (per 100,000 population)']
Indicator6
# Out:
#              ISO3    Type           Country/Region UNICEF Region  \
# 1534     03M49WLD  Region                   Global           NaN
# 1535     03M49WLD  Region                   Global           NaN
# 1536     03M49WLD  Region                   Global           NaN
# 1537     03M49WLD  Region                   Global           NaN
# 1538     03M49WLD  Region                   Global           NaN
# ...           ...     ...                      ...           ...
# 173249  regionWCA  Region  West and Central Africa           NaN
# 173250  regionWCA  Region  West and Central Africa           NaN
# 173251  regionWCA  Region  West and Central Africa           NaN
# 173252  regionWCA  Region  West and Central Africa           NaN
# 173253  regionWCA  Region  West and Central Africa           NaN
#
#                                                 Indicator  \
# 1534    Estimated rate of annual AIDS-related deaths (...
# 1535    Estimated rate of annual AIDS-related deaths (...
# ...

# %%
import sys
# !{sys.executable} -m pip install plotly

# %% [markdown]
# array(['Estimated incidence rate (new HIV infection per 1,000 uninfected population)',
#        'Estimated mother-to-child transmission rate (%)',
#        'Estimated number of annual AIDS-related deaths',
#        'Estimated number of annual new HIV infections',
#        'Estimated number of people living with HIV',
#        'Estimated rate of annual AIDS-related deaths (per 100,000 population)'],
#       dtype=object)
