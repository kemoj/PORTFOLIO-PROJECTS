# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
Test = pd.read_excel("Test PRRDntHalf.xlsx")
Test
# Out:
#       SN     PD0H  tHALFelimination      PRRd1b     PRRd2b  MAFH  TMAFH  Age  \
# 0      1   258823             1.512       85.71   514285.0   NaN    NaN  7.0
# 1      2    72535             1.362       38.01    76595.0  11.0    NaN  4.0
# 2      3    34000             1.731       33.47    50000.0   NaN    NaN  5.5
# 3      4    75044             2.275      500.29    75044.0   2.0   11.0  8.0
# 4      5     3749             1.318     4311.00     4311.0   NaN    NaN  2.5
# ..   ...      ...               ...         ...        ...   ...    ...  ...
# 355  356   870156             1.181   870156.00   870156.0   6.0    NaN  5.0
# 356  357  1096636             1.143  1096636.00  1096636.0   NaN    NaN  4.0
# 357  358    99996             0.738    99996.00    99996.0   4.0    8.0  3.0
# 358  359   536912             0.709   838500.00   838500.0   1.0    2.0  NaN
# 359  360   203592             1.101   203592.00   203592.0   NaN    NaN  3.5
#
#     Sex  duration
# 0     F       3.0
# ...

# %%
Test.describe()
# Out:
#                SN          PD0H  tHALFelimination        PRRd1b        PRRd2b  \
# count  360.000000  3.600000e+02        360.000000  3.600000e+02  3.600000e+02
# mean   180.500000  1.017737e+05          1.179139  9.710832e+04  1.232735e+05
# std    104.067286  1.211983e+05          0.373262  1.305375e+05  1.352599e+05
# min      1.000000  1.800000e+03          0.651000  2.440000e+00  1.628000e+01
# 25%     90.750000  3.600000e+04          0.950750  1.479200e+04  4.733725e+04
# 50%    180.500000  6.633150e+04          1.093000  6.324500e+04  8.679650e+04
# 75%    270.250000  1.200880e+05          1.286000  1.229480e+05  1.500000e+05
# max    360.000000  1.096636e+06          3.035000  1.096636e+06  1.096636e+06
#
#              MAFH       TMAFH         Age    duration
# count  136.000000  168.000000  355.000000  298.000000
# mean     5.191176    8.630952    7.360958    2.713087
# std      3.271685    4.036598    3.155407    1.160110
# ...

# %%
Test.isnull().sum()
# Out:
# SN                    0
# PD0H                  0
# tHALFelimination      0
# PRRd1b                0
# PRRd2b                0
# MAFH                224
# TMAFH               192
# Age                   5
# Sex                   0
# duration             62
# dtype: int64

# %%
test1=Test[["tHALFelimination",'Age',"Sex"]]
print(test1)
# Out:
#      tHALFelimination  Age Sex
# 0               1.512  7.0   F
# 1               1.362  4.0   F
# 2               1.731  5.5   M
# 3               2.275  8.0   M
# 4               1.318  2.5   F
# ..                ...  ...  ..
# 355             1.181  5.0   M
# 356             1.143  4.0   F
# 357             0.738  3.0   F
# 358             0.709  NaN   F
# 359             1.101  3.5   M
#
# [360 rows x 3 columns]

# %%
test2 =test1.dropna()
test2
# Out:
#      tHALFelimination  Age Sex
# 0               1.512  7.0   F
# 1               1.362  4.0   F
# 2               1.731  5.5   M
# 3               2.275  8.0   M
# 4               1.318  2.5   F
# ..                ...  ...  ..
# 354             0.655  8.5   F
# 355             1.181  5.0   M
# 356             1.143  4.0   F
# 357             0.738  3.0   F
# 359             1.101  3.5   M
#
# [355 rows x 3 columns]

# %%
test2.isnull().sum()
# Out:
# tHALFelimination    0
# Age                 0
# Sex                 0
# dtype: int64

# %%
x=test2.Age
x
# Out:
# 0      7.0
# 1      4.0
# 2      5.5
# 3      8.0
# 4      2.5
#       ...
# 354    8.5
# 355    5.0
# 356    4.0
# 357    3.0
# 359    3.5
# Name: Age, Length: 355, dtype: float64

# %%
y=test2.tHALFelimination
y
# Out:
# 0      1.512
# 1      1.362
# 2      1.731
# 3      2.275
# 4      1.318
#        ...
# 354    0.655
# 355    1.181
# 356    1.143
# 357    0.738
# 359    1.101
# Name: tHALFelimination, Length: 355, dtype: float64

# %%
plt.scatter(x,y)
plt.xlabel("Age",fontsize=20)
plt.ylabel("tHALFelimination",fontsize=20)
plt
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\HP\\anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
z=test2.Sex
z
# Out:
# 0      F
# 1      F
# 2      M
# 3      M
# 4      F
#       ..
# 354    F
# 355    M
# 356    F
# 357    F
# 359    M
# Name: Sex, Length: 355, dtype: object

# %%
plt.scatter(z,y)
plt.xlabel("Sex",fontsize=20)
plt.ylabel("tHALFelimination",fontsize=20)
plt
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\HP\\anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
test2["Sex"].value_counts()

# %%
#Bar chart represents mostly strings
plt.figure(figsize=(25,15))
plt.bar(x,y)
plt.xlabel("Age")
plt.ylabel("tHALFelimination")
plt.title("tHALFelimination vs Age")
plt.show()

# %%
#Bar chart represents mostly strings
plt.figure(figsize=(5,10))
plt.barh(x,y)
plt.xlabel("Age")
plt.ylabel("tHALFelimination")
plt.title("tHALFelimination vs Age")
plt.grid()
plt.show()

# %%
fig=plt.figure(figsize=(20,10))
plt.pie(y, labels=x)
plt.title("tHALFelimination vs sex")
plt.show()

# %%
fig=plt.figure(figsize=(16,5))
sns.barplot(test2["Age"],test2["tHALFelimination"])
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age', ylabel='tHALFelimination'>

# %%
fig=plt.figure(figsize=(5,5))
sns.barplot(test2["Sex"],test2["tHALFelimination"])
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Sex', ylabel='tHALFelimination'>

# %%
test2["Age"].describe()
# Out:
# count    355.000000
# mean       7.360958
# std        3.155407
# min        1.000000
# 25%        5.000000
# 50%        7.000000
# 75%       10.000000
# max       15.000000
# Name: Age, dtype: float64

# %%
X=test2[["Age","Sex"]]
Y=[["tHALFelimination"]]

# %%
test2.info
# Out:
# <bound method DataFrame.info of      tHALFelimination  Age Sex
# 0               1.512  7.0   F
# 1               1.362  4.0   F
# 2               1.731  5.5   M
# 3               2.275  8.0   M
# 4               1.318  2.5   F
# ..                ...  ...  ..
# 354             0.655  8.5   F
# 355             1.181  5.0   M
# 356             1.143  4.0   F
# 357             0.738  3.0   F
# 359             1.101  3.5   M
#
# [355 rows x 3 columns]>

# %%
test2["Sex"]=test2["Sex"].map({"M": 1,"F": 0})
test2["Sex"]
# Out:
# <ipython-input-30-91288dddf440>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test2["Sex"]=test2["Sex"].map({"M": 1,"F": 0})
# 0      0
# 1      0
# 2      1
# 3      1
# 4      0
#       ..
# 354    0
# 355    1
# 356    0
# 357    0
# 359    1
# Name: Sex, Length: 355, dtype: int64

# %%
#visualizing 
fig = plt.figure(figsize=(10,7))
fig.add_subplot(2,1,1)
sns.distplot(test2['Age'])
fig.add_subplot(2,1,2)
sns.boxplot(test2['tHALFelimination'])
plt.tight_layout()
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#visualizing 
fig = plt.figure(figsize=(20,15))
fig.add_subplot(2,2,1)
sns.scatterplot(test2['Age'], test2['tHALFelimination'])
fig.add_subplot(2,2,2)
sns.scatterplot(test2['Sex'],test2['tHALFelimination'])
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Sex', ylabel='tHALFelimination'>

# %%
#data visualization 
fig = plt.figure(figsize=(16,5))
fig.add_subplot(1,2,1)
test2.groupby('Age').mean()['tHALFelimination'].plot()
fig.add_subplot(1,2,2)
test2.groupby('Sex').mean()['tHALFelimination'].plot()
# Out:
# <AxesSubplot:xlabel='Sex'>

# %%
t

# %%
X =test2.drop('tHALFelimination',axis =1).values
y = test2['tHALFelimination'].values
#splitting Train and Test 
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=101)

# %%
#standardization scaler - fit&transform on train, fit only on test
from sklearn.preprocessing import StandardScaler
s_scaler = StandardScaler()
X_train = s_scaler.fit_transform(X_train.astype(np.float))
X_test = s_scaler.transform(X_test.astype(np.float))
# Out:
# <ipython-input-36-71c309465cd7>:4: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   X_train = s_scaler.fit_transform(X_train.astype(np.float))
# <ipython-input-36-71c309465cd7>:5: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   X_test = s_scaler.transform(X_test.astype(np.float))

# %%
# Multiple Liner Regression
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()  
regressor.fit(X_train, y_train)
#evaluate the model (intercept and slope)
print(regressor.intercept_)
print(regressor.coef_)
#predicting the test set result
y_pred = regressor.predict(X_test)
#put results as a DataFrame
coeff_df = pd.DataFrame(regressor.coef_, test2.drop('tHALFelimination',axis =1).columns, columns=['Coefficient']) 
coeff_df
# Out:
# 1.1854303797468355
# [-0.01707218  0.01064226]
#      Coefficient
# Age    -0.017072
# Sex     0.010642
