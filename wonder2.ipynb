# %%
import pandas as pd
import numpy as np
from IPython.display import display
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
data = pd.read_csv("fifa19.csv")
display(data)
# Out:
#        Unnamed: 0      ID                Name  Age  \
# 0               0  158023            L. Messi   31
# 1               1   20801   Cristiano Ronaldo   33
# 2               2  190871           Neymar Jr   26
# 3               3  193080              De Gea   27
# 4               4  192985        K. De Bruyne   27
# ...           ...     ...                 ...  ...
# 18202       18202  238813        J. Lundstram   19
# 18203       18203  243165  N. Christoffersson   19
# 18204       18204  241638           B. Worman   16
# 18205       18205  246268      D. Walker-Rice   17
# 18206       18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# ...

# %%
shape = data.shape
display(shape)
# Out:
# (18207, 89)

# %%
total_columns=data.columns
display(total_columns)
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
# ...

# %%
data.columns.shape
# Out:
# (89,)

# %%
# to get some specific columns 
some = data[["ID", "Name", "Age", "Preferred Foot", "Club", "Nationality"]]
some
# Out:
#            ID                Name  Age Preferred Foot                 Club  \
# 0      158023            L. Messi   31           Left         FC Barcelona
# 1       20801   Cristiano Ronaldo   33          Right             Juventus
# 2      190871           Neymar Jr   26          Right  Paris Saint-Germain
# 3      193080              De Gea   27          Right    Manchester United
# 4      192985        K. De Bruyne   27          Right      Manchester City
# ...       ...                 ...  ...            ...                  ...
# 18202  238813        J. Lundstram   19          Right      Crewe Alexandra
# 18203  243165  N. Christoffersson   19          Right       Trelleborgs FF
# 18204  241638           B. Worman   16          Right     Cambridge United
# 18205  246268      D. Walker-Rice   17          Right      Tranmere Rovers
# 18206  246269           G. Nugent   16          Right      Tranmere Rovers
#
#       Nationality
# 0       Argentina
# 1        Portugal
# ...

# %%
#Lets remove Nationality using POP
some.pop("Nationality")
some
# Out:
#            ID                Name  Age Preferred Foot                 Club
# 0      158023            L. Messi   31           Left         FC Barcelona
# 1       20801   Cristiano Ronaldo   33          Right             Juventus
# 2      190871           Neymar Jr   26          Right  Paris Saint-Germain
# 3      193080              De Gea   27          Right    Manchester United
# 4      192985        K. De Bruyne   27          Right      Manchester City
# ...       ...                 ...  ...            ...                  ...
# 18202  238813        J. Lundstram   19          Right      Crewe Alexandra
# 18203  243165  N. Christoffersson   19          Right       Trelleborgs FF
# 18204  241638           B. Worman   16          Right     Cambridge United
# 18205  246268      D. Walker-Rice   17          Right      Tranmere Rovers
# 18206  246269           G. Nugent   16          Right      Tranmere Rovers
#
# [18207 rows x 5 columns]

# %%
# Out:
# <ipython-input-24-231ef466b313>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   some["Players Hipe"] = some ["Age"].astype(str) + " " + some["Club"]
#            ID                Name  Age Preferred Foot                 Club  \
# 0      158023            L. Messi   31           Left         FC Barcelona
# 1       20801   Cristiano Ronaldo   33          Right             Juventus
# 2      190871           Neymar Jr   26          Right  Paris Saint-Germain
# 3      193080              De Gea   27          Right    Manchester United
# 4      192985        K. De Bruyne   27          Right      Manchester City
# ...       ...                 ...  ...            ...                  ...
# ...

# %%
#Get for a specific country..Nigeria
def country(x):
    return data[data["Nationality"]==x][["Name", 'Potential', "Overall", "Position"]]
country("Nigeria")
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
some["Players Hipe"] = some ["Age"].astype(str) + " " + some["Club"]
some
# Out:
# <ipython-input-26-231ef466b313>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   some["Players Hipe"] = some ["Age"].astype(str) + " " + some["Club"]
#            ID                Name  Age Preferred Foot                 Club  \
# 0      158023            L. Messi   31           Left         FC Barcelona
# 1       20801   Cristiano Ronaldo   33          Right             Juventus
# 2      190871           Neymar Jr   26          Right  Paris Saint-Germain
# 3      193080              De Gea   27          Right    Manchester United
# 4      192985        K. De Bruyne   27          Right      Manchester City
# ...       ...                 ...  ...            ...                  ...
# ...

# %%
some["Players Hipe"]'= some ["Age"].astype(str) + " " + some["Club"]
some
# Out:
#   File "<ipython-input-28-b5446a926041>", line 1
#     some["Players Hipe"]'= some ["Age"].astype(str) + " " + some["Club"]
#                                                                         ^
# SyntaxError: EOL while scanning string literal

# %%
data.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
#Get for a specific country..Nigeria
def country(x):
    return data[data["Nationality"]==x][["Name", 'Potential', "Overall", "Position"]]
country("Nigeria")
# Out:
#               Name  Potential  Overall Position
# 425       W. Ndidi         85       80      LDM
# 789       A. Iwobi         84       78       LM
# 858       V. Moses         78       78       RW
# 1022     O. Ighalo         77       77       ST
# 1296   H. Onyekuru         86       76       ST
# ...            ...        ...      ...      ...
# 17096    J. Kayode         70       55       ST
# 17160     H. Offia         66       55       LM
# 17261    R. Ayagwa         67       55       CM
# 17652     A. Yusuf         69       53       CM
# 18174   S. Adewusi         63       48       CM
#
# [121 rows x 4 columns]

# %%
#Get club FC Barcelonia
def club(x):
    return data[data["Club"]==x][["Name", 'Nationality', "Overall", "Position", "Age", "Jersey Number", "Wage", "Release Clause"]]
club("FC Barcelona")
# Out:
#                   Name  Nationality  Overall Position  Age  Jersey Number  \
# 0             L. Messi    Argentina       94       RF   31           10.0
# 7            L. Suárez      Uruguay       91       RS   31            9.0
# 18       M. ter Stegen      Germany       89       GK   26           22.0
# 20     Sergio Busquets        Spain       89      CDM   29            5.0
# 32            Coutinho       Brazil       88       LW   26            7.0
# 42           S. Umtiti       France       87       CB   24           23.0
# 49          Jordi Alba        Spain       87       LB   29           18.0
# 53          I. Rakitić      Croatia       87      RCM   30            4.0
# 54               Piqué        Spain       87      RCB   31            3.0
# 96            A. Vidal        Chile       85      CAM   31            8.0
# 155         O. Dembélé       France       83       RW   21           11.0
# 192      Sergi Roberto        Spain       83       RB   26           20.0
# ...

# %%
club("Manchester United").count()
# Out:
# Name              33
# Nationality       33
# Overall           33
# Position          33
# Age               33
# Jersey Number     33
# Wage              33
# Release Clause    33
# dtype: int64

# %%
data.isnull().sum()
# Out:
# Unnamed: 0           0
# ID                   0
# Name                 0
# Age                  0
# Photo                0
#                   ...
# GKHandling          48
# GKKicking           48
# GKPositioning       48
# GKReflexes          48
# Release Clause    1564
# Length: 89, dtype: int64

# %%
#To replace GKHandling null values with mean
y = round(data['GKHandling'].mean())
y
# Out:
# 16

# %%
z =data['GKHandling'].fillna(y, inplace = True)
data['GKHandling']
# Out:
# 0        11.0
# 1        11.0
# 2         9.0
# 3        85.0
# 4        13.0
#          ...
# 18202    13.0
# 18203     9.0
# 18204     5.0
# 18205     6.0
# 18206    15.0
# Name: GKHandling, Length: 18207, dtype: float64

# %%
data["GKHandling"].isnull()
#Done.. no null values
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 18202    False
# 18203    False
# 18204    False
# 18205    False
# 18206    False
# Name: GKHandling, Length: 18207, dtype: bool

# %%
gh = data.describe()
gh
# Out:
#          Unnamed: 0             ID           Age       Overall     Potential  \
# count  18207.000000   18207.000000  18207.000000  18207.000000  18207.000000
# mean    9103.000000  214298.338606     25.122206     66.238699     71.307299
# std     5256.052511   29965.244204      4.669943      6.908930      6.136496
# min        0.000000      16.000000     16.000000     46.000000     48.000000
# 25%     4551.500000  200315.500000     21.000000     62.000000     67.000000
# 50%     9103.000000  221759.000000     25.000000     66.000000     71.000000
# 75%    13654.500000  236529.500000     28.000000     71.000000     75.000000
# max    18206.000000  246620.000000     45.000000     94.000000     95.000000
#
#             Special  International Reputation     Weak Foot   Skill Moves  \
# count  18207.000000              18159.000000  18159.000000  18159.000000
# mean    1597.809908                  1.113222      2.947299      2.361308
# ...

# %%
data = pd.read_csv("fifa19.csv")
display(data)
# Out:
#        Unnamed: 0      ID                Name  Age  \
# 0               0  158023            L. Messi   31
# 1               1   20801   Cristiano Ronaldo   33
# 2               2  190871           Neymar Jr   26
# 3               3  193080              De Gea   27
# 4               4  192985        K. De Bruyne   27
# ...           ...     ...                 ...  ...
# 18202       18202  238813        J. Lundstram   19
# 18203       18203  243165  N. Christoffersson   19
# 18204       18204  241638           B. Worman   16
# 18205       18205  246268      D. Walker-Rice   17
# 18206       18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# ...
